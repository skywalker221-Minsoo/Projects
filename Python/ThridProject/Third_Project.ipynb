# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/tjoeun709-10/Desktop/0513/train_ver1.csv')
data
# Out:
#       index gender car reality  child_num  income_total           income_type  \
# 0         1      F   N       Y          0      202500.0  Commercial associate
# 1         2      M   N       Y          0      270000.0  Commercial associate
# 2         3      F   Y       Y          1      157500.0  Commercial associate
# 3         4      M   Y       Y          2      157500.0               Working
# 4         5      F   N       N          0      157500.0  Commercial associate
# 5         6      F   N       Y          0      121500.0  Commercial associate
# 6         7      M   Y       Y          0      135000.0  Commercial associate
# 7         8      F   N       Y          0      135000.0               Working
# 8         9      M   Y       Y          1      270000.0               Working
# 9        10      M   N       N          1      270000.0               Working
# 10       11      M   Y       N          0      405000.0               Working
# 11       12      F   Y       Y          1      225000.0               Working
# 12       13      M   Y       Y          0      135000.0               Working
# 13       14      M   Y       Y          0      225000.0  Commercial associate
# 14       15      F   N       Y          0      297000.0  Commercial associate
# 15       16      F   Y       N          0      202500.0  Commercial associate
# 16       17      M   Y       N          1      337500.0  Commercial associate
# 17       18      F   N       Y          0       54000.0             Pensioner
# 18       19      M   Y       Y          1      180000.0               Working
# 19       20      M   Y       Y          2      360000.0               Working
# 20       21      F   N       N          0      135000.0               Working
# 21       22      F   N       Y          0      189000.0             Pensioner
# 22       23      F   N       Y          0       90000.0             Pensioner
# 23       24      F   N       Y          2       67500.0               Working
# 24       25      F   N       N          0      112500.0             Pensioner
# 25       26      F   N       Y          0       90000.0             Pensioner
# 26       27      M   Y       N          0      202500.0  Commercial associate
# 27       28      F   N       N          2      112500.0         State servant
# 28       29      F   N       N          0       67500.0             Pensioner
# 29       30      F   N       N          0       94500.0             Pensioner
# ...     ...    ...  ..     ...        ...           ...                   ...
# 5970   5971      F   N       Y          3       67500.0  Commercial associate
# 5971   5972      F   N       Y          2      175500.0  Commercial associate
# 5972   5973      M   Y       Y          2      216000.0         State servant
# 5973   5974      F   N       N          2      157500.0               Working
# 5974   5975      M   N       Y          0      225000.0             Pensioner
# 5975   5976      M   Y       N          1      225000.0  Commercial associate
# 5976   5977      F   N       Y          0      225000.0  Commercial associate
# 5977   5978      M   N       Y          1      234000.0               Working
# 5978   5979      F   N       Y          0      270000.0             Pensioner
# 5979   5980      M   Y       Y          0      211500.0  Commercial associate
# 5980   5981      M   Y       Y          0       90000.0             Pensioner
# 5981   5982      F   N       N          0      270000.0         State servant
# 5982   5983      M   N       Y          2      135000.0               Working
# 5983   5984      M   Y       N          0       76500.0               Working
# 5984   5985      F   N       N          0      208350.0             Pensioner
# 5985   5986      F   N       N          0       56250.0             Pensioner
# 5986   5987      F   N       Y          0      202500.0               Working
# 5987   5988      F   N       N          4       67500.0               Working
# 5988   5989      M   Y       Y          0      180000.0               Working
# 5989   5990      M   Y       N          0      135000.0               Working
# 5990   5991      F   Y       N          0       95850.0  Commercial associate
# 5991   5992      F   N       Y          0       90000.0               Working
# 5992   5993      F   Y       Y          0      225000.0               Working
# 5993   5994      F   N       N          1       90000.0               Working
# 5994   5995      F   N       Y          0      220500.0             Pensioner
# 5995   5996      F   N       Y          1      135000.0               Working
# 5996   5997      F   N       Y          0       90000.0               Working
# 5997   5998      F   Y       Y          0      360000.0         State servant
# 5998   5999      F   N       N          1      157500.0               Working
# 5999   6000      M   Y       N          2      450000.0               Working
#
#                            edu_type           family_type         house_type  \
# 0     Secondary / secondary special               Married  House / apartment
# 1     Secondary / secondary special               Married  House / apartment
# 2     Secondary / secondary special               Married  House / apartment
# 3     Secondary / secondary special               Married       With parents
# 4     Secondary / secondary special        Civil marriage  House / apartment
# 5     Secondary / secondary special               Married    Co-op apartment
# 6                  Higher education               Married  House / apartment
# 7                  Higher education               Married  House / apartment
# 8     Secondary / secondary special               Married  House / apartment
# 9     Secondary / secondary special               Married  House / apartment
# 10                 Higher education               Married  House / apartment
# 11                 Higher education             Separated  House / apartment
# 12    Secondary / secondary special               Married  House / apartment
# 13                 Higher education  Single / not married  House / apartment
# 14    Secondary / secondary special  Single / not married   Rented apartment
# 15    Secondary / secondary special        Civil marriage       With parents
# 16                 Higher education             Separated  House / apartment
# 17    Secondary / secondary special               Married  House / apartment
# 18                 Higher education               Married       With parents
# 19    Secondary / secondary special               Married  House / apartment
# 20    Secondary / secondary special               Married  House / apartment
# 21    Secondary / secondary special               Married  House / apartment
# 22    Secondary / secondary special               Married  House / apartment
# 23                 Higher education               Married  House / apartment
# 24    Secondary / secondary special                 Widow  House / apartment
# 25    Secondary / secondary special  Single / not married  House / apartment
# 26    Secondary / secondary special               Married  House / apartment
# 27                 Higher education               Married  House / apartment
# 28                 Higher education                 Widow  House / apartment
# 29    Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 5970  Secondary / secondary special               Married  House / apartment
# 5971               Higher education               Married  House / apartment
# 5972               Higher education               Married  House / apartment
# 5973  Secondary / secondary special               Married  House / apartment
# 5974  Secondary / secondary special                 Widow  House / apartment
# 5975  Secondary / secondary special               Married  House / apartment
# 5976               Higher education               Married  House / apartment
# 5977  Secondary / secondary special               Married  House / apartment
# 5978  Secondary / secondary special                 Widow  House / apartment
# 5979  Secondary / secondary special               Married  House / apartment
# 5980  Secondary / secondary special               Married  House / apartment
# 5981               Higher education               Married  House / apartment
# 5982  Secondary / secondary special               Married  House / apartment
# 5983  Secondary / secondary special               Married  House / apartment
# 5984               Higher education               Married  House / apartment
# 5985  Secondary / secondary special               Married   Office apartment
# 5986  Secondary / secondary special                 Widow  House / apartment
# 5987  Secondary / secondary special               Married  House / apartment
# 5988  Secondary / secondary special               Married  House / apartment
# 5989  Secondary / secondary special               Married  House / apartment
# 5990  Secondary / secondary special               Married  House / apartment
# 5991  Secondary / secondary special             Separated  House / apartment
# 5992               Higher education               Married  House / apartment
# 5993  Secondary / secondary special               Married  House / apartment
# 5994                Lower secondary               Married  House / apartment
# 5995               Higher education               Married  House / apartment
# 5996  Secondary / secondary special               Married  House / apartment
# 5997               Higher education             Separated  House / apartment
# 5998  Secondary / secondary special        Civil marriage  House / apartment
# 5999  Secondary / secondary special               Married  House / apartment
#
#            ...                    occyp_type  family_size  begin_month  \
# 0          ...                   Sales staff            2          -37
# 1          ...                       Drivers            2          -53
# 2          ...                   Accountants            3          -60
# 3          ...                       Drivers            4          -60
# 4          ...                      Laborers            2          -22
# 5          ...                   Sales staff            2          -22
# 6          ...                      Laborers            2          -18
# 7          ...                      Laborers            2           -2
# 8          ...                      Laborers            3          -22
# 9          ...                      Managers            3          -35
# 10         ...         High skill tech staff            2           -4
# 11         ...                    Core staff            2           -2
# 12         ...                   Sales staff            2            0
# 13         ...                   Sales staff            1           -7
# 14         ...                      Laborers            1           -1
# 15         ...                           NaN            2          -33
# 16         ...                      Managers            2          -23
# 17         ...                           NaN            2           -2
# 18         ...                      Laborers            3          -15
# 19         ...                      Managers            4          -33
# 20         ...         Private service staff            2           -2
# 21         ...                           NaN            2          -19
# 22         ...                           NaN            2           -5
# 23         ...                           NaN            4          -12
# 24         ...                           NaN            1          -26
# 25         ...                           NaN            1          -13
# 26         ...                Security staff            2          -22
# 27         ...                    Core staff            4           -3
# 28         ...                           NaN            1          -30
# 29         ...                           NaN            2          -41
# ...        ...                           ...          ...          ...
# 5970       ...                   Sales staff            5          -47
# 5971       ...                   Sales staff            4          -22
# 5972       ...         High skill tech staff            4          -46
# 5973       ...                      Laborers            4          -19
# 5974       ...                           NaN            1          -45
# 5975       ...                      Laborers            3          -32
# 5976       ...                           NaN            2          -44
# 5977       ...                      Laborers            3          -44
# 5978       ...                           NaN            1          -44
# 5979       ...                      Laborers            2          -11
# 5980       ...                           NaN            2          -12
# 5981       ...                   Accountants            2          -40
# 5982       ...                      Laborers            4          -54
# 5983       ...                      Laborers            2          -51
# 5984       ...                           NaN            2          -39
# 5985       ...                           NaN            2          -17
# 5986       ...                           NaN            1           -6
# 5987       ...                           NaN            6          -21
# 5988       ...                       Drivers            2          -10
# 5989       ...                       Drivers            2           -8
# 5990       ...                      Laborers            2          -49
# 5991       ...                           NaN            1          -37
# 5992       ...                    Core staff            2          -39
# 5993       ...                           NaN            3          -10
# 5994       ...                           NaN            2          -47
# 5995       ...                   Accountants            3          -35
# 5996       ...                Cleaning staff            2          -39
# 5997       ...                    Core staff            1          -58
# 5998       ...                 Cooking staff            3          -40
# 5999       ...                       Drivers            4          -18
#
#       begin_month_num  card_using  credit ages  employed_year  \
# 0                  37           3       0   40              6
# 1                  53           4       0   40             15
# 2                  60           5       0   30              6
# 3                  60           5       0   30             12
# 4                  22           2       0   40              4
# 5                  22           2       0   30              5
# 6                  18           2       0   30             10
# 7                   2           0       0   30              5
# 8                  22           2       0   30              5
# 9                  35           3       0   20              2
# 10                  4           0       0   50              9
# 11                  2           0       0   40              5
# 12                  0           0       0   20              3
# 13                  7           1       0   40              7
# 14                  1           0       0   40              9
# 15                 33           3       0   30             15
# 16                 23           2       0   40              1
# 17                  2           0       0   60              0
# 18                 15           1       0   30              5
# 19                 33           3       0   30              3
# 20                  2           0       0   40              3
# 21                 19           2       0   60              0
# 22                  5           0       0   50              0
# 23                 12           1       0   20              3
# 24                 26           2       0   50              0
# 25                 13           1       0   60              0
# 26                 22           2       0   40              8
# 27                  3           0       0   30              8
# 28                 30           3       0   60              0
# 29                 41           3       0   50              0
# ...               ...         ...     ...  ...            ...
# 5970               47           4       2   40              2
# 5971               22           2       2   40              4
# 5972               46           4       2   30              8
# 5973               19           2       2   30             10
# 5974               45           4       2   60              0
# 5975               32           3       2   30              8
# 5976               44           4       2   30              7
# 5977               44           4       2   30              5
# 5978               44           4       2   50              0
# 5979               11           1       2   50              5
# 5980               12           1       2   60              0
# 5981               40           3       2   30              7
# 5982               54           5       2   50             17
# 5983               51           4       2   50              2
# 5984               39           3       2   50              0
# 5985               17           1       2   50              0
# 5986                6           1       2   50              2
# 5987               21           2       2   30             17
# 5988               10           1       2   30              3
# 5989                8           1       2   50              2
# 5990               49           4       2   50             19
# 5991               37           3       2   50             10
# 5992               39           3       2   40              9
# 5993               10           1       2   40              6
# 5994               47           4       2   50              0
# 5995               35           3       2   20              9
# 5996               39           3       2   50              9
# 5997               58           5       2   50              6
# 5998               40           3       2   40             10
# 5999               18           2       2   40             20
#
#       employed_year_5yr_bound  income_quintile
# 0                           2                2
# 1                           3                1
# 2                           2                2
# 3                           3                2
# 4                           1                2
# 5                           1                4
# 6                           2                3
# 7                           1                3
# 8                           1                1
# 9                           1                1
# 10                          2                1
# 11                          1                1
# 12                          1                3
# 13                          2                1
# 14                          2                1
# 15                          3                2
# 16                          1                1
# 17                          0                4
# 18                          1                2
# 19                          1                1
# 20                          1                3
# 21                          0                2
# 22                          0                4
# 23                          1                4
# 24                          0                4
# 25                          0                4
# 26                          2                2
# 27                          2                4
# 28                          0                4
# 29                          0                4
# ...                       ...              ...
# 5970                        1                4
# 5971                        1                2
# 5972                        2                2
# 5973                        2                2
# 5974                        0                1
# 5975                        2                1
# 5976                        2                1
# 5977                        1                1
# 5978                        0                1
# 5979                        1                2
# 5980                        0                4
# 5981                        2                1
# 5982                        4                3
# 5983                        1                4
# 5984                        0                2
# 5985                        0                4
# 5986                        1                2
# 5987                        4                4
# 5988                        1                2
# 5989                        1                3
# 5990                        4                4
# 5991                        2                4
# 5992                        2                1
# 5993                        2                4
# 5994                        0                2
# 5995                        2                3
# 5996                        2                4
# 5997                        2                1
# 5998                        2                2
# 5999                        4                1
#
# [6000 rows x 26 columns]

# %%
corr = data.corr(method='pearson')
corr
# Out:
#                             index  child_num  income_total  DAYS_BIRTH  \
# index                    1.000000   0.010146     -0.018855    0.021658
# child_num                0.010146   1.000000      0.012160   -0.333300
# income_total            -0.018855   0.012160      1.000000   -0.060339
# DAYS_BIRTH               0.021658  -0.333300     -0.060339    1.000000
# DAYS_EMPLOYED            0.016594   0.048211      0.105980   -0.012997
# FLAG_MOBIL                    NaN        NaN           NaN         NaN
# work_phone              -0.014173   0.045946     -0.027309   -0.174111
# phone                   -0.012556  -0.020354      0.011914    0.046769
# email                    0.021491   0.030459      0.078298   -0.111342
# family_size              0.012282   0.886115      0.012771   -0.298156
# begin_month             -0.110947  -0.016107     -0.036354   -0.061548
# begin_month_num          0.110947   0.016107      0.036354    0.061548
# card_using               0.112209   0.019205      0.040114    0.057893
# credit                   0.942809   0.009398     -0.012780    0.021650
# ages                     0.014941  -0.322890     -0.058619    0.971032
# employed_year            0.016611   0.054173      0.109409   -0.028652
# employed_year_5yr_bound  0.013206   0.079556      0.123656   -0.105834
# income_quintile          0.012688  -0.022066     -0.784843    0.103831
#
#                          DAYS_EMPLOYED  FLAG_MOBIL  work_phone     phone  \
# index                         0.016594         NaN   -0.014173 -0.012556
# child_num                     0.048211         NaN    0.045946 -0.020354
# income_total                  0.105980         NaN   -0.027309  0.011914
# DAYS_BIRTH                   -0.012997         NaN   -0.174111  0.046769
# DAYS_EMPLOYED                 1.000000         NaN    0.109588  0.045422
# FLAG_MOBIL                         NaN         NaN         NaN       NaN
# work_phone                    0.109588         NaN    1.000000  0.305556
# phone                         0.045422         NaN    0.305556  1.000000
# email                        -0.004075         NaN   -0.047456  0.007315
# family_size                   0.057261         NaN    0.063210 -0.012839
# begin_month                  -0.096686         NaN   -0.029431 -0.020717
# begin_month_num               0.096686         NaN    0.029431  0.020717
# card_using                    0.100075         NaN    0.026370  0.019134
# credit                        0.013204         NaN   -0.019522 -0.004928
# ages                         -0.006304         NaN   -0.159957  0.047969
# employed_year                 0.998982         NaN    0.115558  0.044553
# employed_year_5yr_bound       0.972339         NaN    0.143870  0.048323
# income_quintile              -0.110291         NaN    0.040051  0.037014
#
#                             email  family_size  begin_month  begin_month_num  \
# index                    0.021491     0.012282    -0.110947         0.110947
# child_num                0.030459     0.886115    -0.016107         0.016107
# income_total             0.078298     0.012771    -0.036354         0.036354
# DAYS_BIRTH              -0.111342    -0.298156    -0.061548         0.061548
# DAYS_EMPLOYED           -0.004075     0.057261    -0.096686         0.096686
# FLAG_MOBIL                    NaN          NaN          NaN              NaN
# work_phone              -0.047456     0.063210    -0.029431         0.029431
# phone                    0.007315    -0.012839    -0.020717         0.020717
# email                    1.000000     0.029342    -0.011497         0.011497
# family_size              0.029342     1.000000    -0.031101         0.031101
# begin_month             -0.011497    -0.031101     1.000000        -1.000000
# begin_month_num          0.011497     0.031101    -1.000000         1.000000
# card_using               0.014426     0.032966    -0.981427         0.981427
# credit                   0.023117     0.012118    -0.107785         0.107785
# ages                    -0.106214    -0.286742    -0.062359         0.062359
# employed_year           -0.001906     0.062917    -0.095451         0.095451
# employed_year_5yr_bound  0.008483     0.086189    -0.094585         0.094585
# income_quintile         -0.066993    -0.013955     0.040708        -0.040708
#
#                          card_using    credit      ages  employed_year  \
# index                      0.112209  0.942809  0.014941       0.016611
# child_num                  0.019205  0.009398 -0.322890       0.054173
# income_total               0.040114 -0.012780 -0.058619       0.109409
# DAYS_BIRTH                 0.057893  0.021650  0.971032      -0.028652
# DAYS_EMPLOYED              0.100075  0.013204 -0.006304       0.998982
# FLAG_MOBIL                      NaN       NaN       NaN            NaN
# work_phone                 0.026370 -0.019522 -0.159957       0.115558
# phone                      0.019134 -0.004928  0.047969       0.044553
# email                      0.014426  0.023117 -0.106214      -0.001906
# family_size                0.032966  0.012118 -0.286742       0.062917
# begin_month               -0.981427 -0.107785 -0.062359      -0.095451
# begin_month_num            0.981427  0.107785  0.062359       0.095451
# card_using                 1.000000  0.109489  0.059415       0.098694
# credit                     0.109489  1.000000  0.014337       0.013421
# ages                       0.059415  0.014337  1.000000      -0.021829
# employed_year              0.098694  0.013421 -0.021829       1.000000
# employed_year_5yr_bound    0.097609  0.009535 -0.095903       0.975869
# income_quintile           -0.046776  0.012085  0.101912      -0.113681
#
#                          employed_year_5yr_bound  income_quintile
# index                                   0.013206         0.012688
# child_num                               0.079556        -0.022066
# income_total                            0.123656        -0.784843
# DAYS_BIRTH                             -0.105834         0.103831
# DAYS_EMPLOYED                           0.972339        -0.110291
# FLAG_MOBIL                                   NaN              NaN
# work_phone                              0.143870         0.040051
# phone                                   0.048323         0.037014
# email                                   0.008483        -0.066993
# family_size                             0.086189        -0.013955
# begin_month                            -0.094585         0.040708
# begin_month_num                         0.094585        -0.040708
# card_using                              0.097609        -0.046776
# credit                                  0.009535         0.012085
# ages                                   -0.095903         0.101912
# employed_year                           0.975869        -0.113681
# employed_year_5yr_bound                 1.000000        -0.129301
# income_quintile                        -0.129301         1.000000

# %% [markdown]
# # DAYS_BIRTH, child_num 0.33 약한 상관관계
# # family_size, child_num 0.89 강한 상관관계
# # DAYS_EMPLOYED, income_total -0.16 약한 음의 상관관계
# # DAYS_BIRTH, DAYS_EMPLOYED -0.61 강한 음의 상관관계
# # family_size, DAYS_EMPLOYED -0.22 약한 음의 상관관계
# # work_phone, DAYS_EMPLOYED -0.24 약한 음의 상관관계
# # income_total, DAYS_EMPLOYED -0.16 약한 음의 상관관계
# # credit, begin_month -0.14 약한 음의 상관관계

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 26 columns):
# index                      6000 non-null int64
# gender                     6000 non-null object
# car                        6000 non-null object
# reality                    6000 non-null object
# child_num                  6000 non-null int64
# income_total               6000 non-null float64
# income_type                6000 non-null object
# edu_type                   6000 non-null object
# family_type                6000 non-null object
# house_type                 6000 non-null object
# DAYS_BIRTH                 6000 non-null int64
# DAYS_EMPLOYED              6000 non-null int64
# FLAG_MOBIL                 6000 non-null int64
# work_phone                 6000 non-null int64
# phone                      6000 non-null int64
# email                      6000 non-null int64
# occyp_type                 4187 non-null object
# family_size                6000 non-null int64
# begin_month                6000 non-null int64
# begin_month_num            6000 non-null int64
# card_using                 6000 non-null int64
# credit                     6000 non-null int64
# ages                       6000 non-null int64
# employed_year              6000 non-null int64
# employed_year_5yr_bound    6000 non-null int64
# income_quintile            6000 non-null int64
# dtypes: float64(1), int64(17), object(8)
# memory usage: 1.2+ MB

# %%
data.isnull().sum()
# Out:
# index                         0
# gender                        0
# car                           0
# reality                       0
# child_num                     0
# income_total                  0
# income_type                   0
# edu_type                      0
# family_type                   0
# house_type                    0
# DAYS_BIRTH                    0
# DAYS_EMPLOYED                 0
# FLAG_MOBIL                    0
# work_phone                    0
# phone                         0
# email                         0
# occyp_type                 1813
# family_size                   0
# begin_month                   0
# begin_month_num               0
# card_using                    0
# credit                        0
# ages                          0
# employed_year                 0
# employed_year_5yr_bound       0
# income_quintile               0
# dtype: int64

# %%
data.groupby(['gender', 'credit'])['credit'].count()
# Out:
# gender  credit
# F       0         1327
#         1         1374
#         2         1326
# M       0          673
#         1          626
#         2          674
# Name: credit, dtype: int64

# %%
data.groupby(['car', 'credit'])['credit'].count()
# Out:
# car  credit
# N    0         1224
#      1         1302
#      2         1234
# Y    0          776
#      1          698
#      2          766
# Name: credit, dtype: int64

# %%
data.groupby(['reality', 'credit'])['credit'].count()
# Out:
# reality  credit
# N        0          652
#          1          618
#          2          700
# Y        0         1348
#          1         1382
#          2         1300
# Name: credit, dtype: int64

# %%
data.groupby(['child_num', 'credit'])['credit'].count()
# Out:
# child_num  credit
# 0          0         1376
#            1         1394
#            2         1382
# 1          0          442
#            1          417
#            2          396
# 2          0          158
#            1          164
#            2          197
# 3          0           16
#            1           19
#            2           19
# 4          0            7
#            1            6
#            2            5
# 5          0            1
#            2            1
# Name: credit, dtype: int64

# %%
data.groupby(['income_total', 'credit'])['credit'].count()
# Out:
# income_total  credit
# 29250.0       0          1
#               1          2
# 31500.0       0          3
#               1          1
#               2          3
# 33300.0       2          1
# 33750.0       2          1
# 36000.0       0          1
# 37800.0       2          1
# 38025.0       2          1
# 38250.0       1          1
# 40500.0       0          1
#               2          2
# 45000.0       0         10
#               1          5
#               2          5
# 46948.5       1          1
# 47250.0       2          1
# 49500.0       0          4
#               1          1
#               2          2
# 50850.0       2          2
# 51750.0       0          1
# 54000.0       0          9
#               1          3
#               2          6
# 56250.0       1          2
#               2          3
# 56700.0       2          1
# 58500.0       0          1
#                         ..
# 540000.0      0          9
#               1          3
#               2          4
# 560250.0      1          2
# 562500.0      0          3
#               1          4
#               2          3
# 585000.0      0          4
#               2          2
# 594000.0      1          1
# 612000.0      0          2
#               2          1
# 630000.0      0          2
#               2          4
# 652500.0      2          1
# 675000.0      0          5
#               1          3
#               2          4
# 716323.5      2          1
# 720000.0      2          1
# 765000.0      0          1
#               1          1
# 787500.0      1          1
# 810000.0      0          1
#               1          1
# 900000.0      0          2
#               2          1
# 945000.0      0          1
# 990000.0      2          1
# 1575000.0     2          1
# Name: credit, Length: 330, dtype: int64

# %%
data['income_total'].describe()
# Out:
# count    6.000000e+03
# mean     1.865369e+05
# std      9.709976e+04
# min      2.925000e+04
# 25%      1.260000e+05
# 50%      1.575000e+05
# 75%      2.250000e+05
# max      1.575000e+06
# Name: income_total, dtype: float64

# %%
data.groupby(['gender', 'credit'])['credit'].count()
# Out:
# gender  credit
# F       0         1327
#         1         1374
#         2         1326
# M       0          673
#         1          626
#         2          674
# Name: credit, dtype: int64

# %%
data.groupby(['income_quintile', 'credit'])['credit'].count()
# Out:
# income_quintile  credit
# 1                0         611
#                  1         526
#                  2         620
# 2                0         600
#                  1         569
#                  2         544
# 3                0         330
#                  1         358
#                  2         347
# 4                0         459
#                  1         547
#                  2         489
# Name: credit, dtype: int64

# %%
data.groupby(['income_quintile', 'reality'])['reality'].count()
# Out:
# income_quintile  reality
# 1                N           556
#                  Y          1201
# 2                N           563
#                  Y          1150
# 3                N           345
#                  Y           690
# 4                N           506
#                  Y           989
# Name: reality, dtype: int64

# %%
data.groupby(['reality', 'car'])['car'].count()
# Out:
# reality  car
# N        N      1220
#          Y       750
# Y        N      2540
#          Y      1490
# Name: car, dtype: int64

# %%
data.groupby(['child_num', 'reality'])['reality'].count()
# Out:
# child_num  reality
# 0          N          1377
#            Y          2775
# 1          N           399
#            Y           856
# 2          N           171
#            Y           348
# 3          N            17
#            Y            37
# 4          N             6
#            Y            12
# 5          Y             2
# Name: reality, dtype: int64

# %%
data.groupby(['family_size', 'reality'])['reality'].count()
# Out:
# family_size  reality
# 1            N           364
#              Y           790
# 2            N          1067
#              Y          2120
# 3            N           353
#              Y           741
# 4            N           164
#              Y           330
# 5            N            16
#              Y            37
# 6            N             6
#              Y            10
# 7            Y             2
# Name: reality, dtype: int64

# %%
data.groupby(['family_size', 'car'])['car'].count()
# Out:
# family_size  car
# 1            N       886
#              Y       268
# 2            N      1973
#              Y      1214
# 3            N       615
#              Y       479
# 4            N       254
#              Y       240
# 5            N        28
#              Y        25
# 6            N         3
#              Y        13
# 7            N         1
#              Y         1
# Name: car, dtype: int64

# %%
data.groupby(['gender', 'car'])['car'].count()
# Out:
# gender  car
# F       N      3010
#         Y      1017
# M       N       750
#         Y      1223
# Name: car, dtype: int64

# %%
data.groupby(['family_size', 'gender', 'car'])['car'].count()
# Out:
# family_size  gender  car
# 1            F       N       732
#                      Y       138
#              M       N       154
#                      Y       130
# 2            F       N      1596
#                      Y       542
#              M       N       377
#                      Y       672
# 3            F       N       468
#                      Y       233
#              M       N       147
#                      Y       246
# 4            F       N       188
#                      Y        84
#              M       N        66
#                      Y       156
# 5            F       N        22
#                      Y        13
#              M       N         6
#                      Y        12
# 6            F       N         3
#                      Y         7
#              M       Y         6
# 7            F       N         1
#              M       Y         1
# Name: car, dtype: int64

# %%
data.groupby(['child_num', 'gender', 'car'])['car'].count()
# Out:
# child_num  gender  car
# 0          F       N      2215
#                    Y       635
#            M       N       513
#                    Y       789
# 1          F       N       564
#                    Y       273
#            M       N       161
#                    Y       257
# 2          F       N       204
#                    Y        88
#            M       N        70
#                    Y       157
# 3          F       N        23
#                    Y        12
#            M       N         6
#                    Y        13
# 4          F       N         3
#                    Y         9
#            M       Y         6
# 5          F       N         1
#            M       Y         1
# Name: car, dtype: int64

# %%
data.groupby(['family_size', 'gender', 'reality'])['reality'].count()
# Out:
# family_size  gender  reality
# 1            F       N           259
#                      Y           611
#              M       N           105
#                      Y           179
# 2            F       N           660
#                      Y          1478
#              M       N           407
#                      Y           642
# 3            F       N           223
#                      Y           478
#              M       N           130
#                      Y           263
# 4            F       N            83
#                      Y           189
#              M       N            81
#                      Y           141
# 5            F       N             9
#                      Y            26
#              M       N             7
#                      Y            11
# 6            F       N             4
#                      Y             6
#              M       N             2
#                      Y             4
# 7            F       Y             1
#              M       Y             1
# Name: reality, dtype: int64

# %%
data.groupby(['child_num', 'gender', 'reality'])['reality'].count()
# Out:
# child_num  gender  reality
# 0          F       N           878
#                    Y          1972
#            M       N           499
#                    Y           803
# 1          F       N           258
#                    Y           579
#            M       N           141
#                    Y           277
# 2          F       N            89
#                    Y           203
#            M       N            82
#                    Y           145
# 3          F       N             9
#                    Y            26
#            M       N             8
#                    Y            11
# 4          F       N             4
#                    Y             8
#            M       N             2
#                    Y             4
# 5          F       Y             1
#            M       Y             1
# Name: reality, dtype: int64

# %%
data.groupby(['family_size', 'gender', 'income_quintile'])['income_quintile'].count()
# Out:
# family_size  gender  income_quintile
# 1            F       1                  223
#                      2                  245
#                      3                  158
#                      4                  244
#              M       1                  114
#                      2                   77
#                      3                   44
#                      4                   49
# 2            F       1                  513
#                      2                  588
#                      3                  387
#                      4                  650
#              M       1                  410
#                      2                  302
#                      3                  159
#                      4                  178
# 3            F       1                  169
#                      2                  196
#                      3                  127
#                      4                  209
#              M       1                  176
#                      2                  123
#                      3                   53
#                      4                   41
# 4            F       1                   55
#                      2                   76
#                      3                   63
#                      4                   78
#              M       1                   89
#                      2                   79
#                      3                   31
#                      4                   23
# 5            F       1                    4
#                      2                    8
#                      3                    9
#                      4                   14
#              M       1                    4
#                      2                    7
#                      3                    4
#                      4                    3
# 6            F       2                    4
#                      4                    6
#              M       2                    6
# 7            F       2                    1
#              M       2                    1
# Name: income_quintile, dtype: int64

# %%
data.groupby(['car', 'gender', 'reality'])['reality'].count()
# Out:
# car  gender  reality
# N    F       N           911
#              Y          2099
#      M       N           309
#              Y           441
# Y    F       N           327
#              Y           690
#      M       N           423
#              Y           800
# Name: reality, dtype: int64

# %%
data.groupby(['car', 'gender', 'income_quintile'])['income_quintile'].count()
# Out:
# car  gender  income_quintile
# N    F       1                  602
#              2                  841
#              3                  573
#              4                  994
#      M       1                  249
#              2                  242
#              3                  135
#              4                  124
# Y    F       1                  362
#              2                  277
#              3                  171
#              4                  207
#      M       1                  544
#              2                  353
#              3                  156
#              4                  170
# Name: income_quintile, dtype: int64

# %%
data.groupby(['car', 'gender', 'reality'])['reality'].count()
# Out:
# car  gender  reality
# N    F       N           911
#              Y          2099
#      M       N           309
#              Y           441
# Y    F       N           327
#              Y           690
#      M       N           423
#              Y           800
# Name: reality, dtype: int64

# %%
data.groupby(['car', 'gender', 'reality'])['reality'].value_counts()
# Out:
# car  gender  reality  reality
# N    F       N        N           911
#              Y        Y          2099
#      M       N        N           309
#              Y        Y           441
# Y    F       N        N           327
#              Y        Y           690
#      M       N        N           423
#              Y        Y           800
# Name: reality, dtype: int64

# %%
data.groupby(['gender', 'car', 'reality'])['reality'].count()
# Out:
# gender  car  reality
# F       N    N           911
#              Y          2099
#         Y    N           327
#              Y           690
# M       N    N           309
#              Y           441
#         Y    N           423
#              Y           800
# Name: reality, dtype: int64

# %%
data.groupby(['gender', 'edu_type', 'income_quintile'])['income_quintile'].count()
# Out:
# gender  edu_type                       income_quintile
# F       Academic degree                1                    5
#         Higher education               1                  432
#                                        2                  349
#                                        3                  173
#                                        4                  205
#         Incomplete higher              1                   27
#                                        2                   46
#                                        3                   26
#                                        4                   27
#         Lower secondary                1                    1
#                                        2                   17
#                                        3                    7
#                                        4                    9
#         Secondary / secondary special  1                  499
#                                        2                  706
#                                        3                  538
#                                        4                  960
# M       Academic degree                2                    1
#                                        3                    1
#         Higher education               1                  278
#                                        2                  134
#                                        3                   55
#                                        4                   35
#         Incomplete higher              1                   45
#                                        2                   34
#                                        3                    7
#                                        4                    6
#         Lower secondary                1                    2
#                                        2                    6
#                                        3                    4
#                                        4                    3
#         Secondary / secondary special  1                  468
#                                        2                  420
#                                        3                  224
#                                        4                  250
# Name: income_quintile, dtype: int64

# %%
data.groupby(['gender', 'family_type', 'income_quintile'])['income_quintile'].count()
# Out:
# gender  family_type           income_quintile
# F       Civil marriage        1                  104
#                               2                  102
#                               3                   55
#                               4                   80
#         Married               1                  572
#                               2                  721
#                               3                  500
#                               4                  837
#         Separated             1                   90
#                               2                   77
#                               3                   43
#                               4                   82
#         Single / not married  1                  148
#                               2                  160
#                               3                   97
#                               4                  113
#         Widow                 1                   50
#                               2                   58
#                               3                   49
#                               4                   89
# M       Civil marriage        1                   57
#                               2                   54
#                               3                   19
#                               4                   31
#         Married               1                  606
#                               2                  453
#                               3                  224
#                               4                  207
#         Separated             1                   28
#                               2                   17
#                               3                   10
#                               4                   11
#         Single / not married  1                   98
#                               2                   71
#                               3                   37
#                               4                   44
#         Widow                 1                    4
#                               3                    1
#                               4                    1
# Name: income_quintile, dtype: int64

# %%
data_M = data[data['gender'] == 'M']
data_F = data[data['gender'] == 'F']

# %%
data_M.groupby(['gender', 'employed_year_5yr_bound', 'income_quintile'])['income_quintile'].count().to_frame()
# Out:
#                                                 income_quintile
# gender employed_year_5yr_bound income_quintile
# M      0                       1                             24
#                                2                             36
#                                3                             27
#                                4                             55
#        1                       1                            386
#                                2                            293
#                                3                            141
#                                4                            146
#        2                       1                            245
#                                2                            179
#                                3                             76
#                                4                             53
#        3                       1                             89
#                                2                             64
#                                3                             30
#                                4                             14
#        4                       1                             36
#                                2                             11
#                                3                              7
#                                4                             15
#        5                       1                             11
#                                2                              6
#                                3                             10
#                                4                              6
#        6                       1                              1
#                                2                              3
#                                4                              3
#        7                       1                              1
#                                2                              2
#                                4                              1
#        8                       4                              1
#        9                       2                              1

# %%
data_F.groupby(['gender', 'employed_year_5yr_bound', 'income_quintile'])['income_quintile'].count().to_frame()
# Out:
#                                                 income_quintile
# gender employed_year_5yr_bound income_quintile
# F      0                       1                            111
#                                2                            210
#                                3                            166
#                                4                            356
#        1                       1                            370
#                                2                            364
#                                3                            285
#                                4                            438
#        2                       1                            239
#                                2                            275
#                                3                            159
#                                4                            231
#        3                       1                            118
#                                2                            128
#                                3                             61
#                                4                             79
#        4                       1                             55
#                                2                             44
#                                3                             27
#                                4                             52
#        5                       1                             38
#                                2                             48
#                                3                             16
#                                4                             25
#        6                       1                             18
#                                2                             31
#                                3                             26
#                                4                             13
#        7                       1                             11
#                                2                             11
#                                3                              3
#                                4                              5
#        8                       1                              3
#                                2                              4
#                                3                              1
#        9                       1                              1
#                                2                              3
#                                4                              2

# %%
data.groupby(['gender', 'card_using', 'income_quintile'])['income_quintile'].count().to_frame()
# Out:
#                                    income_quintile
# gender card_using income_quintile
# F      0          1                            143
#                   2                            171
#                   3                            130
#                   4                            219
#        1          1                            249
#                   2                            267
#                   3                            188
#                   4                            323
#        2          1                            206
#                   2                            220
#                   3                            142
#                   4                            240
#        3          1                            174
#                   2                            203
#                   3                            127
#                   4                            201
#        4          1                            128
#                   2                            179
#                   3                            105
#                   4                            142
#        5          1                             64
#                   2                             78
#                   3                             52
#                   4                             76
# M      0          1                             94
#                   2                             98
#                   3                             51
#                   4                             67
#        1          1                            214
#                   2                            131
#                   3                             76
#                   4                             67
#        2          1                            180
#                   2                            121
#                   3                             57
#                   4                             50
#        3          1                            143
#                   2                            122
#                   3                             58
#                   4                             59
#        4          1                            114
#                   2                             89
#                   3                             35
#                   4                             41
#        5          1                             48
#                   2                             34
#                   3                             14
#                   4                             10

# %%
data.groupby(['gender', 'ages', 'income_quintile'])['income_quintile'].count().to_frame()
# Out:
#                              income_quintile
# gender ages income_quintile
# F      20   1                             66
#             2                            112
#             3                            100
#             4                            146
#        30   1                            317
#             2                            315
#             3                            214
#             4                            292
#        40   1                            293
#             2                            286
#             3                            185
#             4                            231
#        50   1                            218
#             2                            267
#             3                            167
#             4                            340
#        60   1                             70
#             2                            138
#             3                             78
#             4                            192
# M      20   1                            137
#             2                            158
#             3                             68
#             4                             58
#        30   1                            285
#             2                            189
#             3                             90
#             4                             66
#        40   1                            247
#             2                            143
#             3                             70
#             4                             67
#        50   1                            104
#             2                             73
#             3                             46
#             4                             70
#        60   1                             20
#             2                             32
#             3                             17
#             4                             33

# %%
data.groupby(['gender', 'ages', 'card_using'])['card_using'].count().to_frame()
# Out:
#                         card_using
# gender ages card_using
# F      20   0                   92
#             1                  130
#             2                   88
#             3                   54
#             4                   50
#             5                   10
#        30   0                  187
#             1                  278
#             2                  259
#             3                  200
#             4                  151
#             5                   63
#        40   0                  143
#             1                  248
#             2                  191
#             3                  171
#             4                  155
#             5                   87
#        50   0                  151
#             1                  249
#             2                  188
#             3                  197
#             4                  133
#             5                   74
#        60   0                   90
#             1                  122
#             2                   82
#             3                   83
#             4                   65
#             5                   36
# M      20   0                   86
#             1                  123
#             2                  104
#             3                   61
#             4                   37
#             5                   10
#        30   0                   92
#             1                  137
#             2                  125
#             3                  132
#             4                  110
#             5                   34
#        40   0                   64
#             1                  129
#             2                  111
#             3                  114
#             4                   71
#             5                   38
#        50   0                   51
#             1                   72
#             2                   52
#             3                   56
#             4                   41
#             5                   21
#        60   0                   17
#             1                   27
#             2                   16
#             3                   19
#             4                   20
#             5                    3

# %%
#신용 등급 비율
plt.subplots(figsize=(8,8))
plt.pie(data['credit'].value_counts(), labels = data['credit'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio', size=20)
plt.show()
#신용 등급이 낮은 비율이 높다. (0:연체x, 1:연체?, 2:연체o)

# %%
#소득 분위 비율
plt.subplots(figsize=(8,8))
plt.pie(data['income_quintile'].value_counts(), labels = data['income_quintile'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio', size=20)
plt.show()
#1사분위(상위 75~100%): 1, 2사분위(상위 50~75%): 2,
#3사분위(상위 25~50%): 3, 4사분위(상위25% 이하): 4

# %%
#남녀 비율
plt.subplots(figsize=(8,8))
plt.pie(data['gender'].value_counts(), labels = data['gender'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Gender Ratio', size=20)
plt.show()
#여성: 66.89%, 남성: 33.11%

# %%
#신용 등급에 따른 남녀 비율
data_credit0 = data[data['credit']==0]
data_credit1 = data[data['credit']==1]
data_credit2 = data[data['credit']==2]

# %%
def cat_plot(column):
    f, ax = plt.subplots(1, 3, figsize=(15, 6))
    
    sns.countplot(x=column,
                 data=data_credit0,
                  ax=ax[0],
                  order=data_credit0[column].value_counts().index)
    ax[0].tick_params(labelsize=12)
    ax[0].set_title('Credit = 0')
    ax[0].set_ylabel('count')
    ax[0].tick_params(rotation=50)
    
    sns.countplot(x=column,
                 data=data_credit1,
                  ax=ax[1],
                  order=data_credit1[column].value_counts().index)
    ax[1].tick_params(labelsize=12)
    ax[1].set_title('Credit = 1')
    ax[1].set_ylabel('count')
    ax[1].tick_params(rotation=50)
    
    sns.countplot(x=column,
                 data=data_credit2,
                  ax=ax[2],
                  order=data_credit2[column].value_counts().index)
    ax[2].tick_params(labelsize=12)
    ax[2].set_title('Credit = 2')
    ax[2].set_ylabel('count')
    ax[2].tick_params(rotation=50)
    
    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
cat_plot('gender')
#모든 등급에서 남녀 비율이 거의 비슷하다.

# %%
#남성 데이터 총 1973
data_M = data[data['gender']=='M']
data_M
# Out:
#       index gender car reality  child_num  income_total           income_type  \
# 1         2      M   N       Y          0      270000.0  Commercial associate
# 3         4      M   Y       Y          2      157500.0               Working
# 6         7      M   Y       Y          0      135000.0  Commercial associate
# 8         9      M   Y       Y          1      270000.0               Working
# 9        10      M   N       N          1      270000.0               Working
# 10       11      M   Y       N          0      405000.0               Working
# 12       13      M   Y       Y          0      135000.0               Working
# 13       14      M   Y       Y          0      225000.0  Commercial associate
# 16       17      M   Y       N          1      337500.0  Commercial associate
# 18       19      M   Y       Y          1      180000.0               Working
# 19       20      M   Y       Y          2      360000.0               Working
# 26       27      M   Y       N          0      202500.0  Commercial associate
# 31       32      M   N       Y          0      292500.0  Commercial associate
# 36       37      M   Y       N          2      135000.0               Working
# 37       38      M   N       Y          1       90000.0  Commercial associate
# 45       46      M   N       Y          0      180000.0  Commercial associate
# 48       49      M   N       Y          0       31500.0             Pensioner
# 51       52      M   Y       Y          0       94500.0             Pensioner
# 53       54      M   N       Y          2      148500.0  Commercial associate
# 54       55      M   N       Y          0      270000.0               Working
# 55       56      M   N       Y          2      112500.0               Working
# 57       58      M   N       Y          0      270000.0               Working
# 58       59      M   Y       N          1      135000.0               Working
# 60       61      M   N       N          0      121500.0               Working
# 63       64      M   Y       Y          0      270000.0               Working
# 65       66      M   N       Y          0       49500.0             Pensioner
# 66       67      M   N       Y          0      450000.0  Commercial associate
# 68       69      M   N       N          0      135000.0               Working
# 69       70      M   N       N          1      225000.0  Commercial associate
# 71       72      M   N       Y          1      225000.0               Working
# ...     ...    ...  ..     ...        ...           ...                   ...
# 5909   5910      M   N       N          0      202500.0         State servant
# 5913   5914      M   Y       N          2      315000.0  Commercial associate
# 5917   5918      M   N       Y          0      126000.0               Working
# 5919   5920      M   N       N          0      270000.0         State servant
# 5925   5926      M   N       Y          0      225000.0         State servant
# 5928   5929      M   Y       Y          0      315000.0               Working
# 5929   5930      M   Y       Y          0      103500.0               Working
# 5932   5933      M   N       Y          0      157500.0               Working
# 5937   5938      M   Y       N          0      234000.0               Working
# 5941   5942      M   N       Y          0      157500.0               Working
# 5948   5949      M   N       N          0      247500.0  Commercial associate
# 5953   5954      M   Y       N          0      225000.0               Working
# 5957   5958      M   Y       Y          2      225000.0               Working
# 5960   5961      M   Y       N          1      135000.0               Working
# 5961   5962      M   N       N          0       90000.0               Working
# 5962   5963      M   Y       Y          2      180000.0               Working
# 5964   5965      M   N       N          1      207000.0         State servant
# 5966   5967      M   Y       Y          0      202500.0               Working
# 5969   5970      M   Y       N          0      112500.0               Working
# 5972   5973      M   Y       Y          2      216000.0         State servant
# 5974   5975      M   N       Y          0      225000.0             Pensioner
# 5975   5976      M   Y       N          1      225000.0  Commercial associate
# 5977   5978      M   N       Y          1      234000.0               Working
# 5979   5980      M   Y       Y          0      211500.0  Commercial associate
# 5980   5981      M   Y       Y          0       90000.0             Pensioner
# 5982   5983      M   N       Y          2      135000.0               Working
# 5983   5984      M   Y       N          0       76500.0               Working
# 5988   5989      M   Y       Y          0      180000.0               Working
# 5989   5990      M   Y       N          0      135000.0               Working
# 5999   6000      M   Y       N          2      450000.0               Working
#
#                            edu_type           family_type  \
# 1     Secondary / secondary special               Married
# 3     Secondary / secondary special               Married
# 6                  Higher education               Married
# 8     Secondary / secondary special               Married
# 9     Secondary / secondary special               Married
# 10                 Higher education               Married
# 12    Secondary / secondary special               Married
# 13                 Higher education  Single / not married
# 16                 Higher education             Separated
# 18                 Higher education               Married
# 19    Secondary / secondary special               Married
# 26    Secondary / secondary special               Married
# 31                 Higher education  Single / not married
# 36                 Higher education               Married
# 37    Secondary / secondary special               Married
# 45    Secondary / secondary special               Married
# 48    Secondary / secondary special               Married
# 51    Secondary / secondary special               Married
# 53    Secondary / secondary special               Married
# 54    Secondary / secondary special               Married
# 55    Secondary / secondary special               Married
# 57    Secondary / secondary special               Married
# 58                 Higher education               Married
# 60    Secondary / secondary special               Married
# 63    Secondary / secondary special  Single / not married
# 65    Secondary / secondary special        Civil marriage
# 66    Secondary / secondary special  Single / not married
# 68    Secondary / secondary special        Civil marriage
# 69    Secondary / secondary special               Married
# 71    Secondary / secondary special               Married
# ...                             ...                   ...
# 5909               Higher education               Married
# 5913  Secondary / secondary special               Married
# 5917  Secondary / secondary special               Married
# 5919  Secondary / secondary special  Single / not married
# 5925  Secondary / secondary special               Married
# 5928  Secondary / secondary special        Civil marriage
# 5929  Secondary / secondary special               Married
# 5932              Incomplete higher               Married
# 5937  Secondary / secondary special               Married
# 5941  Secondary / secondary special               Married
# 5948  Secondary / secondary special               Married
# 5953  Secondary / secondary special  Single / not married
# 5957  Secondary / secondary special               Married
# 5960  Secondary / secondary special               Married
# 5961  Secondary / secondary special               Married
# 5962               Higher education               Married
# 5964               Higher education               Married
# 5966               Higher education               Married
# 5969  Secondary / secondary special               Married
# 5972               Higher education               Married
# 5974  Secondary / secondary special                 Widow
# 5975  Secondary / secondary special               Married
# 5977  Secondary / secondary special               Married
# 5979  Secondary / secondary special               Married
# 5980  Secondary / secondary special               Married
# 5982  Secondary / secondary special               Married
# 5983  Secondary / secondary special               Married
# 5988  Secondary / secondary special               Married
# 5989  Secondary / secondary special               Married
# 5999  Secondary / secondary special               Married
#
#                house_type       ...                    occyp_type  \
# 1       House / apartment       ...                       Drivers
# 3            With parents       ...                       Drivers
# 6       House / apartment       ...                      Laborers
# 8       House / apartment       ...                      Laborers
# 9       House / apartment       ...                      Managers
# 10      House / apartment       ...         High skill tech staff
# 12      House / apartment       ...                   Sales staff
# 13      House / apartment       ...                   Sales staff
# 16      House / apartment       ...                      Managers
# 18           With parents       ...                      Laborers
# 19      House / apartment       ...                      Managers
# 26      House / apartment       ...                Security staff
# 31       Rented apartment       ...                   Sales staff
# 36      House / apartment       ...                    Core staff
# 37           With parents       ...                      Laborers
# 45      House / apartment       ...                Security staff
# 48      House / apartment       ...                           NaN
# 51      House / apartment       ...                           NaN
# 53    Municipal apartment       ...                      Laborers
# 54      House / apartment       ...                      Laborers
# 55      House / apartment       ...                      Laborers
# 57           With parents       ...                      Laborers
# 58      House / apartment       ...                      Laborers
# 60      House / apartment       ...                      Laborers
# 63      House / apartment       ...                      Laborers
# 65      House / apartment       ...                           NaN
# 66           With parents       ...                      Managers
# 68       Office apartment       ...            Low-skill Laborers
# 69           With parents       ...                       Drivers
# 71      House / apartment       ...                      Laborers
# ...                   ...       ...                           ...
# 5909    House / apartment       ...                    Core staff
# 5913    House / apartment       ...                      Laborers
# 5917    House / apartment       ...                      Laborers
# 5919         With parents       ...                    Core staff
# 5925    House / apartment       ...                      Laborers
# 5928    House / apartment       ...                   Sales staff
# 5929    House / apartment       ...                           NaN
# 5932    House / apartment       ...                           NaN
# 5937    House / apartment       ...                      Laborers
# 5941    House / apartment       ...                      Laborers
# 5948     Rented apartment       ...                Security staff
# 5953    House / apartment       ...                       Drivers
# 5957    House / apartment       ...                Security staff
# 5960    House / apartment       ...                      Managers
# 5961    House / apartment       ...                      Laborers
# 5962    House / apartment       ...                      Laborers
# 5964     Office apartment       ...                    Core staff
# 5966    House / apartment       ...                      Managers
# 5969    House / apartment       ...                   Sales staff
# 5972    House / apartment       ...         High skill tech staff
# 5974    House / apartment       ...                           NaN
# 5975    House / apartment       ...                      Laborers
# 5977    House / apartment       ...                      Laborers
# 5979    House / apartment       ...                      Laborers
# 5980    House / apartment       ...                           NaN
# 5982    House / apartment       ...                      Laborers
# 5983    House / apartment       ...                      Laborers
# 5988    House / apartment       ...                       Drivers
# 5989    House / apartment       ...                       Drivers
# 5999    House / apartment       ...                       Drivers
#
#       family_size  begin_month  begin_month_num  card_using  credit ages  \
# 1               2          -53               53           4       0   40
# 3               4          -60               60           5       0   30
# 6               2          -18               18           2       0   30
# 8               3          -22               22           2       0   30
# 9               3          -35               35           3       0   20
# 10              2           -4                4           0       0   50
# 12              2            0                0           0       0   20
# 13              1           -7                7           1       0   40
# 16              2          -23               23           2       0   40
# 18              3          -15               15           1       0   30
# 19              4          -33               33           3       0   30
# 26              2          -22               22           2       0   40
# 31              1           -7                7           1       0   20
# 36              4          -42               42           4       0   30
# 37              3          -20               20           2       0   20
# 45              2          -11               11           1       0   50
# 48              2           -7                7           1       0   60
# 51              2          -10               10           1       0   50
# 53              4            0                0           0       0   40
# 54              2          -30               30           3       0   50
# 55              4           -1                1           0       0   50
# 57              2          -34               34           3       0   40
# 58              3          -18               18           2       0   30
# 60              2          -47               47           4       0   20
# 63              1           -7                7           1       0   30
# 65              2           -1                1           0       0   60
# 66              1          -16               16           1       0   20
# 68              2          -35               35           3       0   30
# 69              3          -21               21           2       0   40
# 71              3          -15               15           1       0   40
# ...           ...          ...              ...         ...     ...  ...
# 5909            2          -17               17           1       2   30
# 5913            4          -34               34           3       2   40
# 5917            2          -31               31           3       2   20
# 5919            1          -21               21           2       2   20
# 5925            2          -51               51           4       2   30
# 5928            2          -15               15           1       2   20
# 5929            2          -13               13           1       2   50
# 5932            2          -39               39           3       2   30
# 5937            2          -19               19           2       2   50
# 5941            2          -14               14           1       2   30
# 5948            2          -39               39           3       2   50
# 5953            1          -15               15           1       2   20
# 5957            4           -6                6           1       2   40
# 5960            3          -24               24           2       2   30
# 5961            2          -11               11           1       2   30
# 5962            4          -25               25           2       2   50
# 5964            3          -36               36           3       2   40
# 5966            2          -49               49           4       2   40
# 5969            2          -43               43           4       2   30
# 5972            4          -46               46           4       2   30
# 5974            1          -45               45           4       2   60
# 5975            3          -32               32           3       2   30
# 5977            3          -44               44           4       2   30
# 5979            2          -11               11           1       2   50
# 5980            2          -12               12           1       2   60
# 5982            4          -54               54           5       2   50
# 5983            2          -51               51           4       2   50
# 5988            2          -10               10           1       2   30
# 5989            2           -8                8           1       2   50
# 5999            4          -18               18           2       2   40
#
#       employed_year  employed_year_5yr_bound  income_quintile
# 1                15                        3                1
# 3                12                        3                2
# 6                10                        2                3
# 8                 5                        1                1
# 9                 2                        1                1
# 10                9                        2                1
# 12                3                        1                3
# 13                7                        2                1
# 16                1                        1                1
# 18                5                        1                2
# 19                3                        1                1
# 26                8                        2                2
# 31                4                        1                1
# 36                5                        1                3
# 37                1                        1                4
# 45               10                        2                2
# 48                0                        0                4
# 51                0                        0                4
# 53               13                        3                3
# 54                9                        2                1
# 55               28                        6                4
# 57                8                        2                1
# 58                3                        1                3
# 60                2                        1                4
# 63                5                        1                1
# 65                0                        0                4
# 66                4                        1                1
# 68                5                        1                3
# 69                6                        2                1
# 71                5                        1                1
# ...             ...                      ...              ...
# 5909             14                        3                2
# 5913              8                        2                1
# 5917              2                        1                3
# 5919              6                        2                1
# 5925              1                        1                1
# 5928              6                        2                1
# 5929              4                        1                4
# 5932              2                        1                2
# 5937              3                        1                1
# 5941              5                        1                2
# 5948              5                        1                1
# 5953              2                        1                1
# 5957             13                        3                1
# 5960              5                        1                3
# 5961              5                        1                4
# 5962              4                        1                2
# 5964              8                        2                2
# 5966              6                        2                2
# 5969              7                        2                4
# 5972              8                        2                2
# 5974              0                        0                1
# 5975              8                        2                1
# 5977              5                        1                1
# 5979              5                        1                2
# 5980              0                        0                4
# 5982             17                        4                3
# 5983              2                        1                4
# 5988              3                        1                2
# 5989              2                        1                3
# 5999             20                        4                1
#
# [1973 rows x 26 columns]

# %%
#남성의 신용등급 분포도
plt.subplots(figsize=(8,8))
plt.pie(data_M['credit'].value_counts(), labels = data_M['credit'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio of Male', size=20)
plt.show()

# %%
#여성 데이터 총 4027
data_F = data[data['gender']=='F']
data_F
# Out:
#       index gender car reality  child_num  income_total           income_type  \
# 0         1      F   N       Y          0      202500.0  Commercial associate
# 2         3      F   Y       Y          1      157500.0  Commercial associate
# 4         5      F   N       N          0      157500.0  Commercial associate
# 5         6      F   N       Y          0      121500.0  Commercial associate
# 7         8      F   N       Y          0      135000.0               Working
# 11       12      F   Y       Y          1      225000.0               Working
# 14       15      F   N       Y          0      297000.0  Commercial associate
# 15       16      F   Y       N          0      202500.0  Commercial associate
# 17       18      F   N       Y          0       54000.0             Pensioner
# 20       21      F   N       N          0      135000.0               Working
# 21       22      F   N       Y          0      189000.0             Pensioner
# 22       23      F   N       Y          0       90000.0             Pensioner
# 23       24      F   N       Y          2       67500.0               Working
# 24       25      F   N       N          0      112500.0             Pensioner
# 25       26      F   N       Y          0       90000.0             Pensioner
# 27       28      F   N       N          2      112500.0         State servant
# 28       29      F   N       N          0       67500.0             Pensioner
# 29       30      F   N       N          0       94500.0             Pensioner
# 30       31      F   Y       N          0      562500.0               Working
# 32       33      F   Y       Y          0      225000.0               Working
# 33       34      F   Y       Y          1      157500.0         State servant
# 34       35      F   N       Y          0      315000.0               Working
# 35       36      F   N       N          0       67500.0  Commercial associate
# 38       39      F   N       Y          0      112500.0               Working
# 39       40      F   N       N          0      135000.0  Commercial associate
# 40       41      F   N       Y          0      112500.0             Pensioner
# 41       42      F   N       N          2      382500.0         State servant
# 42       43      F   Y       Y          0      463500.0               Working
# 43       44      F   Y       N          0      225000.0               Working
# 44       45      F   Y       Y          0      432000.0  Commercial associate
# ...     ...    ...  ..     ...        ...           ...                   ...
# 5951   5952      F   Y       N          1      135000.0  Commercial associate
# 5952   5953      F   Y       Y          0      180000.0  Commercial associate
# 5954   5955      F   N       N          0       74250.0               Working
# 5955   5956      F   N       N          0      157500.0  Commercial associate
# 5956   5957      F   N       N          0       76500.0               Working
# 5958   5959      F   Y       Y          2      135000.0               Working
# 5959   5960      F   N       Y          0      166500.0               Working
# 5963   5964      F   N       Y          0      207000.0               Working
# 5965   5966      F   N       N          0      103500.0             Pensioner
# 5967   5968      F   Y       Y          1      157500.0               Working
# 5968   5969      F   N       N          0      135000.0             Pensioner
# 5970   5971      F   N       Y          3       67500.0  Commercial associate
# 5971   5972      F   N       Y          2      175500.0  Commercial associate
# 5973   5974      F   N       N          2      157500.0               Working
# 5976   5977      F   N       Y          0      225000.0  Commercial associate
# 5978   5979      F   N       Y          0      270000.0             Pensioner
# 5981   5982      F   N       N          0      270000.0         State servant
# 5984   5985      F   N       N          0      208350.0             Pensioner
# 5985   5986      F   N       N          0       56250.0             Pensioner
# 5986   5987      F   N       Y          0      202500.0               Working
# 5987   5988      F   N       N          4       67500.0               Working
# 5990   5991      F   Y       N          0       95850.0  Commercial associate
# 5991   5992      F   N       Y          0       90000.0               Working
# 5992   5993      F   Y       Y          0      225000.0               Working
# 5993   5994      F   N       N          1       90000.0               Working
# 5994   5995      F   N       Y          0      220500.0             Pensioner
# 5995   5996      F   N       Y          1      135000.0               Working
# 5996   5997      F   N       Y          0       90000.0               Working
# 5997   5998      F   Y       Y          0      360000.0         State servant
# 5998   5999      F   N       N          1      157500.0               Working
#
#                            edu_type           family_type  \
# 0     Secondary / secondary special               Married
# 2     Secondary / secondary special               Married
# 4     Secondary / secondary special        Civil marriage
# 5     Secondary / secondary special               Married
# 7                  Higher education               Married
# 11                 Higher education             Separated
# 14    Secondary / secondary special  Single / not married
# 15    Secondary / secondary special        Civil marriage
# 17    Secondary / secondary special               Married
# 20    Secondary / secondary special               Married
# 21    Secondary / secondary special               Married
# 22    Secondary / secondary special               Married
# 23                 Higher education               Married
# 24    Secondary / secondary special                 Widow
# 25    Secondary / secondary special  Single / not married
# 27                 Higher education               Married
# 28                 Higher education                 Widow
# 29    Secondary / secondary special               Married
# 30                 Higher education               Married
# 32                 Higher education        Civil marriage
# 33    Secondary / secondary special               Married
# 34    Secondary / secondary special             Separated
# 35    Secondary / secondary special        Civil marriage
# 38    Secondary / secondary special                 Widow
# 39    Secondary / secondary special               Married
# 40    Secondary / secondary special               Married
# 41    Secondary / secondary special               Married
# 42                 Higher education               Married
# 43    Secondary / secondary special                 Widow
# 44                Incomplete higher               Married
# ...                             ...                   ...
# 5951  Secondary / secondary special               Married
# 5952               Higher education               Married
# 5954               Higher education             Separated
# 5955               Higher education               Married
# 5956  Secondary / secondary special               Married
# 5958  Secondary / secondary special               Married
# 5959  Secondary / secondary special  Single / not married
# 5963  Secondary / secondary special               Married
# 5965  Secondary / secondary special               Married
# 5967               Higher education  Single / not married
# 5968  Secondary / secondary special               Married
# 5970  Secondary / secondary special               Married
# 5971               Higher education               Married
# 5973  Secondary / secondary special               Married
# 5976               Higher education               Married
# 5978  Secondary / secondary special                 Widow
# 5981               Higher education               Married
# 5984               Higher education               Married
# 5985  Secondary / secondary special               Married
# 5986  Secondary / secondary special                 Widow
# 5987  Secondary / secondary special               Married
# 5990  Secondary / secondary special               Married
# 5991  Secondary / secondary special             Separated
# 5992               Higher education               Married
# 5993  Secondary / secondary special               Married
# 5994                Lower secondary               Married
# 5995               Higher education               Married
# 5996  Secondary / secondary special               Married
# 5997               Higher education             Separated
# 5998  Secondary / secondary special        Civil marriage
#
#                house_type       ...                    occyp_type  \
# 0       House / apartment       ...                   Sales staff
# 2       House / apartment       ...                   Accountants
# 4       House / apartment       ...                      Laborers
# 5         Co-op apartment       ...                   Sales staff
# 7       House / apartment       ...                      Laborers
# 11      House / apartment       ...                    Core staff
# 14       Rented apartment       ...                      Laborers
# 15           With parents       ...                           NaN
# 17      House / apartment       ...                           NaN
# 20      House / apartment       ...         Private service staff
# 21      House / apartment       ...                           NaN
# 22      House / apartment       ...                           NaN
# 23      House / apartment       ...                           NaN
# 24      House / apartment       ...                           NaN
# 25      House / apartment       ...                           NaN
# 27      House / apartment       ...                    Core staff
# 28      House / apartment       ...                           NaN
# 29      House / apartment       ...                           NaN
# 30      House / apartment       ...                      Managers
# 32      House / apartment       ...                   Sales staff
# 33      House / apartment       ...                      Laborers
# 34      House / apartment       ...                      Laborers
# 35      House / apartment       ...                           NaN
# 38      House / apartment       ...                      Laborers
# 39      House / apartment       ...                           NaN
# 40      House / apartment       ...                           NaN
# 41      House / apartment       ...                Security staff
# 42      House / apartment       ...                      Managers
# 43      House / apartment       ...                   Sales staff
# 44      House / apartment       ...                      Managers
# ...                   ...       ...                           ...
# 5951    House / apartment       ...                      Managers
# 5952    House / apartment       ...                    Core staff
# 5954  Municipal apartment       ...                    Core staff
# 5955    House / apartment       ...         High skill tech staff
# 5956    House / apartment       ...                           NaN
# 5958    House / apartment       ...                       Drivers
# 5959         With parents       ...                   Sales staff
# 5963    House / apartment       ...                           NaN
# 5965    House / apartment       ...                           NaN
# 5967    House / apartment       ...                           NaN
# 5968    House / apartment       ...                           NaN
# 5970    House / apartment       ...                   Sales staff
# 5971    House / apartment       ...                   Sales staff
# 5973    House / apartment       ...                      Laborers
# 5976    House / apartment       ...                           NaN
# 5978    House / apartment       ...                           NaN
# 5981    House / apartment       ...                   Accountants
# 5984    House / apartment       ...                           NaN
# 5985     Office apartment       ...                           NaN
# 5986    House / apartment       ...                           NaN
# 5987    House / apartment       ...                           NaN
# 5990    House / apartment       ...                      Laborers
# 5991    House / apartment       ...                           NaN
# 5992    House / apartment       ...                    Core staff
# 5993    House / apartment       ...                           NaN
# 5994    House / apartment       ...                           NaN
# 5995    House / apartment       ...                   Accountants
# 5996    House / apartment       ...                Cleaning staff
# 5997    House / apartment       ...                    Core staff
# 5998    House / apartment       ...                 Cooking staff
#
#       family_size  begin_month  begin_month_num  card_using  credit ages  \
# 0               2          -37               37           3       0   40
# 2               3          -60               60           5       0   30
# 4               2          -22               22           2       0   40
# 5               2          -22               22           2       0   30
# 7               2           -2                2           0       0   30
# 11              2           -2                2           0       0   40
# 14              1           -1                1           0       0   40
# 15              2          -33               33           3       0   30
# 17              2           -2                2           0       0   60
# 20              2           -2                2           0       0   40
# 21              2          -19               19           2       0   60
# 22              2           -5                5           0       0   50
# 23              4          -12               12           1       0   20
# 24              1          -26               26           2       0   50
# 25              1          -13               13           1       0   60
# 27              4           -3                3           0       0   30
# 28              1          -30               30           3       0   60
# 29              2          -41               41           3       0   50
# 30              2          -12               12           1       0   40
# 32              2          -17               17           1       0   30
# 33              3          -23               23           2       0   30
# 34              1          -18               18           2       0   40
# 35              2          -10               10           1       0   20
# 38              1           -3                3           0       0   40
# 39              2          -31               31           3       0   30
# 40              2           -5                5           0       0   50
# 41              4          -33               33           3       0   50
# 42              2          -34               34           3       0   50
# 43              1           -1                1           0       0   30
# 44              2          -31               31           3       0   30
# ...           ...          ...              ...         ...     ...  ...
# 5951            3          -48               48           4       2   20
# 5952            2          -17               17           1       2   50
# 5954            1          -34               34           3       2   50
# 5955            2          -30               30           3       2   30
# 5956            2          -10               10           1       2   40
# 5958            4          -31               31           3       2   30
# 5959            1          -10               10           1       2   20
# 5963            2           -6                6           1       2   50
# 5965            2          -52               52           4       2   60
# 5967            2          -49               49           4       2   40
# 5968            2          -25               25           2       2   50
# 5970            5          -47               47           4       2   40
# 5971            4          -22               22           2       2   40
# 5973            4          -19               19           2       2   30
# 5976            2          -44               44           4       2   30
# 5978            1          -44               44           4       2   50
# 5981            2          -40               40           3       2   30
# 5984            2          -39               39           3       2   50
# 5985            2          -17               17           1       2   50
# 5986            1           -6                6           1       2   50
# 5987            6          -21               21           2       2   30
# 5990            2          -49               49           4       2   50
# 5991            1          -37               37           3       2   50
# 5992            2          -39               39           3       2   40
# 5993            3          -10               10           1       2   40
# 5994            2          -47               47           4       2   50
# 5995            3          -35               35           3       2   20
# 5996            2          -39               39           3       2   50
# 5997            1          -58               58           5       2   50
# 5998            3          -40               40           3       2   40
#
#       employed_year  employed_year_5yr_bound  income_quintile
# 0                 6                        2                2
# 2                 6                        2                2
# 4                 4                        1                2
# 5                 5                        1                4
# 7                 5                        1                3
# 11                5                        1                1
# 14                9                        2                1
# 15               15                        3                2
# 17                0                        0                4
# 20                3                        1                3
# 21                0                        0                2
# 22                0                        0                4
# 23                3                        1                4
# 24                0                        0                4
# 25                0                        0                4
# 27                8                        2                4
# 28                0                        0                4
# 29                0                        0                4
# 30                8                        2                1
# 32                2                        1                1
# 33               10                        2                2
# 34               10                        2                1
# 35                4                        1                4
# 38               12                        3                4
# 39                6                        2                3
# 40                0                        0                4
# 41               14                        3                1
# 42               12                        3                1
# 43                2                        1                1
# 44                4                        1                1
# ...             ...                      ...              ...
# 5951              2                        1                3
# 5952             19                        4                2
# 5954             15                        3                4
# 5955             14                        3                2
# 5956              1                        1                4
# 5958              1                        1                3
# 5959              2                        1                2
# 5963              2                        1                2
# 5965              0                        0                4
# 5967              5                        1                2
# 5968              0                        0                3
# 5970              2                        1                4
# 5971              4                        1                2
# 5973             10                        2                2
# 5976              7                        2                1
# 5978              0                        0                1
# 5981              7                        2                1
# 5984              0                        0                2
# 5985              0                        0                4
# 5986              2                        1                2
# 5987             17                        4                4
# 5990             19                        4                4
# 5991             10                        2                4
# 5992              9                        2                1
# 5993              6                        2                4
# 5994              0                        0                2
# 5995              9                        2                3
# 5996              9                        2                4
# 5997              6                        2                1
# 5998             10                        2                2
#
# [4027 rows x 26 columns]

# %%
#여성의 신용등급 분포도
plt.subplots(figsize=(8,8))
plt.pie(data_F['credit'].value_counts(), labels = data_F['credit'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio of Male', size=20)
plt.show()

# %%
#성별로 본 결과, 데이터의 신용등급 비율이 거의 일정함을 알 수 있음.

# %%
#이번에는 신용등급으로 보는 소득 사분위 분포
cat_plot('income_quintile')

# %%
#남성의 소득 사분위 분포도
plt.subplots(figsize=(8,8))
plt.pie(data_M['income_quintile'].value_counts(), labels = data_M['income_quintile'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio of Male', size=20)
plt.show()

# %%
#여성의 소득 사분위 분포도
plt.subplots(figsize=(8,8))
plt.pie(data_F['income_quintile'].value_counts(), labels = data_F['income_quintile'].value_counts().index,
       autopct="%.2f%%", shadow=True, startangle=90)
plt.title('Credit Rate Ratio of Female', size=20)
plt.show()

# %%
cat_plot('car')

# %%
#모든 등급에서 차의 여부는 비슷하다.

# %%
#신용등급 별 부동산 소유 여부는 비슷.
cat_plot('reality')

# %%
#신용등급 별 수입방법도 비슷.
cat_plot('income_type')

# %%
#교육 분포도 비슷.
cat_plot('edu_type')

# %%
#성별 분포도 비교

def gender_plot(column):
    f, ax = plt.subplots(1, 2, figsize=(10, 6))

    sns.countplot(x=column,
                 data=data_M,
                  ax=ax[0],
                  order=data_M[column].value_counts().index)
    ax[0].tick_params(labelsize=12)
    ax[0].set_title('Male')
    ax[0].set_ylabel('count')
    ax[0].tick_params(rotation=50)

    sns.countplot(x=column,
                 data=data_F,
                  ax=ax[1],
                  order=data_F[column].value_counts().index)
    ax[1].tick_params(labelsize=12)
    ax[1].set_title('Female')
    ax[1].set_ylabel('count')
    ax[1].tick_params(rotation=50)
    
    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
#여성은 차가 없는것이 대부분이고, 남성은 차가 있는것이 대부분.
gender_plot('car')

# %%
#남녀 둘다 부동산을 가지고 있는 편.
gender_plot('reality')

# %%
#남녀 소득 방법
gender_plot('income_type')

# %%
#남녀 교육수준
gender_plot('edu_type')

# %%
#소득분위별 비율을 알아보자.
data_quintile1 = data[data['income_quintile']==1]
data_quintile2 = data[data['income_quintile']==2]
data_quintile3 = data[data['income_quintile']==3]
data_quintile4 = data[data['income_quintile']==4]

# %%
def quintile_plot(column):
    f, ax = plt.subplots(2, 2, figsize=(20, 30))
    
    sns.countplot(x=column,
                 data=data_quintile1,
                  ax=ax[0][0],
                  order=data_quintile1[column].value_counts().index)
    ax[0][0].tick_params(labelsize=12)
    ax[0][0].set_title('Income_quintile = 1')
    ax[0][0].set_ylabel('count')
    ax[0][0].tick_params(rotation=50)
    
    sns.countplot(x=column,
                 data=data_quintile2,
                  ax=ax[0][1],
                  order=data_quintile2[column].value_counts().index)
    ax[0][1].tick_params(labelsize=12)
    ax[0][1].set_title('Income_quintile = 2')
    ax[0][1].set_ylabel('count')
    ax[0][1].tick_params(rotation=50)
    
    sns.countplot(x=column,
                 data=data_quintile3,
                  ax=ax[1][0],
                  order=data_quintile3[column].value_counts().index)
    ax[1][0].tick_params(labelsize=12)
    ax[1][0].set_title('Income_quintile = 3')
    ax[1][0].set_ylabel('count')
    ax[1][0].tick_params(rotation=50)
    
    sns.countplot(x=column,
                 data=data_quintile4,
                  ax=ax[1][1],
                  order=data_quintile4[column].value_counts().index)
    ax[1][1].tick_params(labelsize=12)
    ax[1][1].set_title('Income_quintile = 4')
    ax[1][1].set_ylabel('count')
    ax[1][1].tick_params(rotation=50)
    
    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
#소득이 1분위이면 차가 있는 비율이 좀더 높음.
quintile_plot('car')

# %%
#부동산은 소득분위 상관없이 다 있음.
quintile_plot('reality')

# %%
#소득분위에 상관없이 working 비율이 가장 높고,
#소득분위가 높아질수록 상업관련 직종이 많아진다.
quintile_plot('income_type')

# %%
#소득에 상관없이 대부분이 아이가 없다.
quintile_plot('child_num')

# %%
quintile_plot('family_type')

# %%
quintile_plot('house_type')

# %%
quintile_plot('family_size')

# %%
def num_plot(column):
  
  fig, axes = plt.subplots(1, 3, figsize=(16, 6))


  sns.distplot(data_credit0[column],
                ax = axes[0])
  axes[0].tick_params(labelsize=12)
  axes[0].set_title('credit = 0')
  axes[0].set_ylabel('count')

  sns.distplot(data_credit1[column],
                ax = axes[1])
  axes[1].tick_params(labelsize=12)
  axes[1].set_title('credit = 1')
  axes[1].set_ylabel('count')

  sns.distplot(data_credit2[column],
                ax = axes[2])
  axes[2].tick_params(labelsize=12)
  axes[2].set_title('credit = 2')
  axes[2].set_ylabel('count')
  plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %%
num_plot('DAYS_BIRTH')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
